# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import and process the dataset of Roblox stock information.

# %%
from os.path import abspath
from darts import TimeSeries

# Read /data/RBLX.csv as a pandas dataframe
df = pd.read_csv(abspath('../data/RBLX.csv'))

series = TimeSeries.from_dataframe(df, time_col='Date', value_cols='Open', freq='D')

# Plot the series using a line graph
series.plot()
# Out:
# /usr/local/Caskroom/miniconda/base/envs/StockMarket/lib/python3.9/site-packages/darts/timeseries.py:39: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   VALID_INDEX_TYPES = (pd.DatetimeIndex, pd.RangeIndex, pd.Int64Index)
# /usr/local/Caskroom/miniconda/base/envs/StockMarket/lib/python3.9/site-packages/darts/timeseries.py:512: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   times: Union[pd.DatetimeIndex, pd.Int64Index],
# /usr/local/Caskroom/miniconda/base/envs/StockMarket/lib/python3.9/site-packages/darts/timeseries.py:738: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   def time_index(self) -> Union[pd.DatetimeIndex, pd.Int64Index]:
# /usr/local/Caskroom/miniconda/base/envs/StockMarket/lib/python3.9/site-packages/darts/timeseries.py:2947: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /usr/local/Caskroom/miniconda/base/envs/StockMarket/lib/python3.9/site-packages/darts/timeseries.py:414: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   time_index = pd.Int64Index(df[time_col].astype(int))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
